# %%
import pandas as pd

data1 = pd.read_excel('./completedata.xlsx')
data1
# Out:
#     Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)         RO         AC  \
# 0                                        2010.0  22.750117  22.080082
# 1                                        2011.0  22.238351  21.027156
# 2                                        2012.0  21.745582  20.059707
# 3                                        2013.0  21.271700  19.178069
# 4                                        2014.0  20.817021  18.368068
# 5                                        2015.0  20.381494  17.629773
# 6                                        2016.0  19.960271  16.953824
# 7                                        2017.0  19.553323  16.340536
# 8                                        2018.0  19.165524  15.780250
# 9                                        2019.0  18.787334  15.273094
# 10                                       2020.0  18.428315  14.814524
# 11                                       2021.0  18.078928  14.399403
# ...

# %%
data2 = round(data1,2)
data2.head()
# Out:
#    Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)     RO     AC     AM     RR  \
# 0                                       2010.0  22.75  22.08  22.20  18.37
# 1                                       2011.0  22.24  21.03  21.43  18.16
# 2                                       2012.0  21.75  20.06  20.71  17.96
# 3                                       2013.0  21.27  19.18  20.03  17.76
# 4                                       2014.0  20.82  18.37  19.38  17.57
#
#       PA    AP      TO     MA     PI  ...        ES.1         RJ.1  \
# 0  20.30  24.58  19.39  29.02  23.45  ...  27048997.0  184310915.0
# 1  19.57  24.34  18.69  27.50  22.60  ...  31519106.0  202640789.0
# 2  18.89  24.11  18.04  26.08  21.81  ...  39732638.0  241206738.0
# 3  18.26  23.88  17.43  24.75  21.07  ...  47020588.0  269830061.0
# 4  17.65  23.67  16.86  23.52  20.37  ...  53463868.0  299738183.0
#
#           SP.1         PR.1        SC.1         RS.1        MS.1        MT.1  \
# ...

# %%
data3 = pd.to_datetime(data2['Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)'], format = '%Y')
data3
# Out:
# 0    2010-01-01
# 1    2011-01-01
# 2    2012-01-01
# 3    2013-01-01
# 4    2014-01-01
# 5    2015-01-01
# 6    2016-01-01
# 7    2017-01-01
# 8    2018-01-01
# 9    2019-01-01
# 10   2020-01-01
# 11   2021-01-01
# 12   2022-01-01
# 13   2023-01-01
# 14   2024-01-01
# 15   2025-01-01
# 16   2026-01-01
# 17   2027-01-01
# 18   2028-01-01
# 19   2029-01-01
# 20   2030-01-01
# 21   2031-01-01
# 22   2032-01-01
# 23   2033-01-01
# 24   2034-01-01
# 25   2035-01-01
# 26   2036-01-01
# 27   2037-01-01
# 28   2038-01-01
# 29   2039-01-01
# 30   2040-01-01
# 31   2041-01-01
# 32   2042-01-01
# 33   2043-01-01
# 34   2044-01-01
# 35   2045-01-01
# 36   2046-01-01
# 37   2047-01-01
# 38   2048-01-01
# 39   2049-01-01
# 40   2050-01-01
# 41   2051-01-01
# 42   2052-01-01
# 43   2053-01-01
# 44   2054-01-01
# 45   2055-01-01
# 46   2056-01-01
# 47   2057-01-01
# 48   2058-01-01
# 49   2059-01-01
# 50          NaT
# Name: Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%), dtype: datetime64[ns]

# %%
data2['Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)'] = data3

# %%
data2.head()
# Out:
#   Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)     RO     AC     AM     RR  \
# 0                                  2010-01-01  22.75  22.08  22.20  18.37
# 1                                  2011-01-01  22.24  21.03  21.43  18.16
# 2                                  2012-01-01  21.75  20.06  20.71  17.96
# 3                                  2013-01-01  21.27  19.18  20.03  17.76
# 4                                  2014-01-01  20.82  18.37  19.38  17.57
#
#       PA    AP      TO     MA     PI  ...        ES.1         RJ.1  \
# 0  20.30  24.58  19.39  29.02  23.45  ...  27048997.0  184310915.0
# 1  19.57  24.34  18.69  27.50  22.60  ...  31519106.0  202640789.0
# 2  18.89  24.11  18.04  26.08  21.81  ...  39732638.0  241206738.0
# 3  18.26  23.88  17.43  24.75  21.07  ...  47020588.0  269830061.0
# 4  17.65  23.67  16.86  23.52  20.37  ...  53463868.0  299738183.0
#
#           SP.1         PR.1        SC.1         RS.1        MS.1        MT.1  \
# ...

# %%
data2.columns
# Out:
# Index(['Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)', 'RO', 'AC', 'AM', 'RR',
#        'PA', 'AP ', 'TO', 'MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'SE', 'BA',
#        'MG', 'ES', 'RJ', 'SP', 'PR', 'SC', 'RS', 'MS', 'MT', 'GO', 'DF',
#        'ANO PIB', 'RO.1', 'AC.1', 'AM.1', 'RR.1', 'PA.1', 'AP', 'TO.1', 'MA.1',
#        'PI.1', 'CE.1', 'RN.1', 'PB.1', 'PE.1', 'AL.1', 'SE.1', 'BA.1', 'MG.1',
#        'ES.1', 'RJ.1', 'SP.1', 'PR.1', 'SC.1', 'RS.1', 'MS.1', 'MT.1', 'GO.1',
#        'DF.1'],
#       dtype='object')

# %%
# going to split to 2 dataframes (Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%) and PIB)
dataTMI = data2.drop(columns=[ 'ANO PIB', 'RO.1', 'AC.1', 'AM.1', 'RR.1', 'PA.1', 'AP', 'TO.1', 'MA.1',
       'PI.1', 'CE.1', 'RN.1', 'PB.1', 'PE.1', 'AL.1', 'SE.1', 'BA.1', 'MG.1',
       'ES.1', 'RJ.1', 'SP.1', 'PR.1', 'SC.1', 'RS.1', 'MS.1', 'MT.1', 'GO.1',
       'DF.1'])
dataTMI1 = dataTMI
dataTMI1['Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)'] = pd.to_datetime(data2['Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)'], format = '%Y')
dataTMI1.head()
# Out:
#   Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)     RO     AC     AM     RR  \
# 0                                  2010-01-01  22.75  22.08  22.20  18.37
# 1                                  2011-01-01  22.24  21.03  21.43  18.16
# 2                                  2012-01-01  21.75  20.06  20.71  17.96
# 3                                  2013-01-01  21.27  19.18  20.03  17.76
# 4                                  2014-01-01  20.82  18.37  19.38  17.57
#
#       PA    AP      TO     MA     PI  ...     ES     RJ     SP     PR     SC  \
# 0  20.30  24.58  19.39  29.02  23.45  ...  11.97  14.06  11.98  12.05  11.20
# 1  19.57  24.34  18.69  27.50  22.60  ...  11.30  13.60  11.58  11.53  10.82
# 2  18.89  24.11  18.04  26.08  21.81  ...  10.69  13.14  11.19  11.04  10.47
# 3  18.26  23.88  17.43  24.75  21.07  ...  10.14  12.71  10.83  10.57  10.12
# 4  17.65  23.67  16.86  23.52  20.37  ...   9.64  12.29  10.49  10.13   9.80
#
#       RS     MS     MT     GO     DF
# ...

# %%
dataPIB = data2.drop(columns=[ 'Ano/ TAXA DE MORTALIDADE INFANTIL - TMI (%)', 'RO', 'AC', 'AM', 'RR',
       'PA', 'AP ', 'TO', 'MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'SE', 'BA',
       'MG', 'ES', 'RJ', 'SP', 'PR', 'SC', 'RS', 'MS', 'MT', 'GO', 'DF'])
dataPIB
# Out:
#     ANO PIB        RO.1        AC.1         AM.1        RR.1         PA.1  \
# 0    2002.0   7467630.0   2971301.0   22093338.0   2392033.0   26482159.0
# 1    2003.0   9425010.0   3377234.0   25862134.0   2594081.0   30270152.0
# 2    2004.0  11004641.0   3784003.0   31090696.0   2822757.0   37272726.0
# 3    2005.0  12511821.0   4300581.0   33980877.0   3193430.0   40522893.0
# 4    2006.0  13054713.0   4661807.0   39933213.0   3802452.0   45983027.0
# 5    2007.0  14438376.0   5458172.0   43479773.0   4203302.0   51846876.0
# 6    2008.0  17285542.0   6410255.0   48115265.0   4841862.0   60956978.0
# 7    2009.0  19725010.0   7407821.0   50559840.0   5671975.0   61665096.0
# 8    2010.0  23907887.0   8342356.0   60877123.0   6639150.0   82684518.0
# 9    2011.0  27574714.0   8949434.0   70734401.0   7303719.0   98710736.0
# 10   2012.0  30112720.0  10137925.0   72242701.0   7711467.0  107080881.0
# 11   2013.0  31121413.0  11473930.0   83051233.0   9010725.0  121224847.0
# ...

# %%
#creating PIB dataframe and removing nan values

dataPIB = pd.read_excel('completedata.xlsx',usecols=  ['ANO PIB', 'RO.1', 'AC.1', 'AM.1', 'RR.1', 'PA.1', 'AP', 'TO.1', 'MA.1',
       'PI.1', 'CE.1', 'RN.1', 'PB.1', 'PE.1', 'AL.1', 'SE.1', 'BA.1', 'MG.1',
       'ES.1', 'RJ.1', 'SP.1', 'PR.1', 'SC.1', 'RS.1', 'MS.1', 'MT.1', 'GO.1',
       'DF.1'], dtype={'RO.1': float, 'AC.1': float, 'AM.1': float, 'RR.1':float, 'PA.1':float, 'AP':float, 'TO.1':float, 
                       'MA.1':float,'PI.1':float, 'CE.1':float, 'RN.1':float, 'PB.1':float, 'PE.1':float, 'AL.1':float, 
                       'SE.1':float, 'BA.1':float, 'MG.1':float, 'ES.1':float, 'RJ.1':float, 'SP.1':float, 'PR.1':float, 
                       'SC.1':float, 'RS.1':float, 'MS.1':float, 'MT.1':float, 'GO.1':float,'DF.1': float})
dataPIB = dataPIB.dropna()
dataPIB['ANO PIB'] = pd.to_datetime(dataPIB['ANO PIB'], format = '%Y')
dataPIB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 16
# Data columns (total 28 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ANO PIB  17 non-null     datetime64[ns]
#  1   RO.1     17 non-null     float64
#  2   AC.1     17 non-null     float64
#  3   AM.1     17 non-null     float64
#  4   RR.1     17 non-null     float64
#  5   PA.1     17 non-null     float64
#  6   AP       17 non-null     float64
#  7   TO.1     17 non-null     float64
#  8   MA.1     17 non-null     float64
#  9   PI.1     17 non-null     float64
#  10  CE.1     17 non-null     float64
#  11  RN.1     17 non-null     float64
#  12  PB.1     17 non-null     float64
#  13  PE.1     17 non-null     float64
#  14  AL.1     17 non-null     float64
#  15  SE.1     17 non-null     float64
#  16  BA.1     17 non-null     float64
#  17  MG.1     17 non-null     float64
#  18  ES.1     17 non-null     float64
#  19  RJ.1     17 non-null     float64
# ...

# %%
dataTMI1.describe()
# Out:
#               RO         AC         AM        RR         PA        AP   \
# count  51.000000  51.000000  51.000000  51.00000  51.000000  51.000000
# mean   15.246275  12.942353  13.613333  14.21098  12.372157  19.850000
# std     3.360996   3.001268   3.252178   2.27182   2.975223   2.546668
# min    11.180000  10.710000  10.550000  10.68000   9.610000  15.990000
# 25%    12.390000  10.875000  11.070000  12.27000  10.055000  17.660000
# 50%    14.380000  11.490000  12.290000  14.06000  11.150000  19.630000
# 75%    17.580000  13.855000  15.285000  16.06500  13.875000  21.910000
# max    22.750000  22.080000  22.200000  18.37000  20.300000  24.580000
#
#               TO         MA         PI         CE  ...         ES         RJ  \
# count  51.000000  51.000000  51.000000  51.000000  ...  51.000000  51.000000
# mean   11.856863  14.106667  13.440196  10.650196  ...   6.400000   7.337843
# std     2.810517   5.202252   4.036474   2.874030  ...   1.814625   2.945507
# ...

# %%
dataPIB.head()
# Out:
#      ANO PIB        RO.1       AC.1        AM.1       RR.1        PA.1  \
# 0 2002-01-01   7467630.0  2971301.0  22093338.0  2392033.0  26482159.0
# 1 2003-01-01   9425010.0  3377234.0  25862134.0  2594081.0  30270152.0
# 2 2004-01-01  11004641.0  3784003.0  31090696.0  2822757.0  37272726.0
# 3 2005-01-01  12511821.0  4300581.0  33980877.0  3193430.0  40522893.0
# 4 2006-01-01  13054713.0  4661807.0  39933213.0  3802452.0  45983027.0
#
#           AP       TO.1        MA.1        PI.1  ...        ES.1         RJ.1  \
# 0  3173343.0  5322563.0  15924003.0   7122635.0  ...  27048997.0  184310915.0
# 1  3413195.0  6612339.0  19502900.0   8414901.0  ...  31519106.0  202640789.0
# 2  3824740.0  7251580.0  22127132.0   9406461.0  ...  39732638.0  241206738.0
# 3  4306410.0  7707340.0  25104209.0  10711834.0  ...  47020588.0  269830061.0
# 4  5280822.0  8655613.0  29710643.0  13360478.0  ...  53463868.0  299738183.0
#
# ...

# %%
feature = dataPIB.columns[1:28]
feature
enumerate(feature)

# %%
#it doesnt look like we have any outliers
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.figure(figsize=(20,30))

for i in enumerate(feature):
    plt.subplot(27,1,i[0]+1)
    sns.distplot(dataPIB[i[1]])
